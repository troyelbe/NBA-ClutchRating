# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
from sklearn.preprocessing import MinMaxScaler

# %%
import pandas as pd
import os

# List of CSV filenames
file_names = [
    '2010-11 NBA - Sheet1.csv', '2003-04 NBA - Sheet1.csv',
    '2004-05 NBA - Sheet1 (1).csv', '2009-10 NBA - Sheet1.csv',
    '2021-22 NBA - Sheet1.csv', '2018-19 NBA - Sheet1 (1).csv',
    '2013-14 NBA - Sheet1.csv', '2019-20 NBA - Sheet1.csv',
    '2012-13 NBA - Sheet1.csv', '2020-21 NBA - Sheet1.csv',
    '2016-17 NBA - Sheet1.csv', '2017-18 NBA - Sheet1.csv',
    '2005-06 NBA - Sheet1.csv', '2007-08 NBA - Sheet1.csv',
    '2015-16 NBA - Sheet1.csv', '2014-15 NBA - Sheet1 (1).csv',
    '2011-12 NBA - Sheet1.csv', '2008-09 NBA - Sheet1.csv',
    '2006-07 NBA - Sheet1.csv', '2002-03 NBA - Sheet1.csv'
]

# Optional: set folder if files are in a specific subdirectory
folder = '.'  # or something like 'nba_data'

# Read and combine all CSVs
all_dataframes = []
for file in file_names:
    path = os.path.join(folder, file)
    df = pd.read_csv(path)
    df['Season'] = file.split(' ')[0]  # Add a 'Season' column from filename
    all_dataframes.append(df)

# Combine all into a single DataFrame
allstar_stats = pd.concat(all_dataframes, ignore_index=True)

# Preview the combined DataFrame
allstar_stats
# Out:
#               Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  ORB  \
# 0          Ray Allen  SG   35  BOS  80  80  36.1  6.0  12.2  0.491  ...  0.6
# 1    Carmelo Anthony  SF   26  TOT  77  77  35.7  8.9  19.5  0.455  ...  1.5
# 2         Chris Bosh  PF   26  MIA  77  77  36.3  6.8  13.7  0.496  ...  1.8
# 3        Kobe Bryant  SG   32  LAL  82  82  33.9  9.0  20.0  0.451  ...  1.0
# 4         Tim Duncan   C   34  SAS  76  76  28.4  5.5  11.0  0.500  ...  2.2
# ..               ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 515      Paul Pierce  SG   25  BOS  79  79  39.2  8.4  20.2  0.416  ...  1.3
# 516  Peja Stojaković  SF   25  SAC  72  72  34.0  6.9  14.4  0.481  ...  0.8
# 517   Antoine Walker  PF   26  BOS  78  78  41.5  7.7  19.9  0.388  ...  1.3
# 518      Ben Wallace   C   28  DET  73  73  39.4  2.9   6.0  0.481  ...  4.0
# 519     Chris Webber  PF   29  SAC  67  67  39.1  9.9  21.4  0.461  ...  2.4
#
#       DRB   TRB  AST  STL  BLK  TOV   PF   PTS   Season
# 0     2.8   3.4  2.7  1.0  0.2  1.5  1.8  16.5  2010-11
# 1     5.8   7.3  2.9  0.9  0.6  2.7  2.9  25.6  2010-11
# 2     6.5   8.3  1.9  0.8  0.6  1.8  2.2  18.7  2010-11
# 3     4.1   5.1  4.7  1.2  0.1  3.0  2.1  25.3  2010-11
# 4     6.7   8.9  2.7  0.7  1.9  1.6  1.6  13.4  2010-11
# ..    ...   ...  ...  ...  ...  ...  ...   ...      ...
# 515   6.0   7.3  4.4  1.8  0.8  3.6  2.9  25.9  2002-03
# 516   4.7   5.5  2.0  1.0  0.1  1.4  2.0  19.2  2002-03
# 517   5.9   7.2  4.8  1.5  0.4  3.3  2.8  20.1  2002-03
# 518  11.4  15.4  1.6  1.4  3.2  1.2  2.5   6.9  2002-03
# 519   8.1  10.5  5.4  1.6  1.3  3.2  3.0  23.0  2002-03
#
# [520 rows x 30 columns]

# %%
sql_connect = sqlite3.connect('nba.sqlite')
common_player_info = pd.read_sql_query('select * from common_player_info', sql_connect)
common_player_info =common_player_info.drop(columns=['display_fi_last','jersey','team_abbreviation','team_city', 'display_first_last','last_affiliation','playercode','player_slug'])

# %%
team_gamests = pd.read_sql_query("select season_id, team_name_home,game_date, season_type,plus_minus_away, plus_minus_home,pts_away from game where game_date > '2002 -11-01 00:00:00'",sql_connect)
salary= pd.read_csv(r'NBASalaryData03-17.csv')
salary.columns = salary.columns.str.lower().str.strip()
allstar_stats.columns = allstar_stats.columns.str.lower().str.strip()

# %%
salary.columns = salary.columns.str.lower().str.strip()
allstar_stats.columns = allstar_stats.columns.str.lower().str.strip()

# %%
#adding 20 to the season column to merge tables
allstar_stats['season'] = allstar_stats['season'].apply(lambda s: s[:4] + '-' + '20' + s[-2:])

# %%
clt = allstar_stats[allstar_stats['player']== 'Kemba Walker']
clt
# Out:
#            player pos  age   tm   g  gs    mp   fg   fga    fg%  ...  orb  \
# 153  Kemba Walker  PG   28  CHO  82  82  34.9  8.9  20.5  0.434  ...  0.6
# 202  Kemba Walker  PG   29  BOS  56  56  31.1  6.8  15.9  0.425  ...  0.6
# 279  Kemba Walker  PG   26  CHO  79  79  34.7  8.1  18.3  0.444  ...  0.6
# 307  Kemba Walker  PG   27  CHO  80  80  34.2  7.4  17.0  0.431  ...  0.4
#
#      drb  trb  ast  stl  blk  tov   pf   pts     season
# 153  3.8  4.4  5.9  1.2  0.4  2.6  1.6  25.6  2018-2019
# 202  3.2  3.9  4.8  0.9  0.5  2.1  1.6  20.4  2019-2020
# 279  3.3  3.9  5.5  1.1  0.3  2.1  1.5  23.2  2016-2017
# 307  2.7  3.1  5.6  1.1  0.3  2.2  1.2  22.1  2017-2018
#
# [4 rows x 30 columns]

# %%
matched_players = allstar_stats.merge(salary, on=['player','season'], how='inner')
#matched_players.drop(columns='
#testing to make sure data comes back correct
allstar_salary = matched_players[matched_players['player'] == 'Kevin Garnett']

# %%
matched_players = matched_players.sort_values('team')

# %%
matched_players['season'].max()
# Out:
# '2017-2018'

# %%
matched_players['season'].min()
# Out:
# '2002-2003'

# %%
sum_teams = matched_players['team'].value_counts()
sum_teams
# Out:
# team
# Boston Celtics            24
# Miami Heat                24
# San Antonio Spurs         20
# Los Angeles Lakers        17
# Atlanta Hawks             16
# Houston Rockets           16
# Phoenix Suns              15
# Cleveland Cavaliers       15
# Detroit Pistons           15
# Toronto Raptors           14
# Oklahoma City Thunder     14
# Golden State Warriors     13
# Indiana Pacers            13
# LA Clippers               13
# Washington Wizards        12
# Orlando Magic             11
# Dallas Mavericks          11
# Chicago Bulls             11
# Portland Trail Blazers    10
# New York Knicks           10
# Minnesota Timberwolves     9
# New Jersey Nets            9
# New Orleans Hornets        9
# Utah Jazz                  7
# Memphis Grizzlies          7
# New Orleans Pelicans       6
# Philadelphia 76ers         5
# Denver Nuggets             5
# Seattle SuperSonics        5
# Sacramento Kings           3
# Charlotte Hornets          2
# Brooklyn Nets              2
# Milwaukee Bucks            2
# Charlotte Bobcats          1
# Name: count, dtype: int64

# %%
sum_teams.plot(kind='bar', figsize=(12,6), title='All-Star Selections by Team 2002- 2018')
plt.xlabel('Team')
plt.ylabel('Number of All-Stars')
plt.tight_layout()
plt.show()

# %%
cor_map = matched_players.select_dtypes(include='number').corr()
cor_map
# Out:
#              age         g        gs        mp        fg       fga       fg%  \
# age     1.000000 -0.111819 -0.124159 -0.353342 -0.272906 -0.239322 -0.046756
# g      -0.111819  1.000000  0.996497  0.259444  0.069332  0.041635  0.057384
# gs     -0.124159  0.996497  1.000000  0.259037  0.070474  0.040850  0.061996
# mp     -0.353342  0.259444  0.259037  1.000000  0.456276  0.520307 -0.206691
# fg     -0.272906  0.069332  0.070474  0.456276  1.000000  0.911449  0.095364
# fga    -0.239322  0.041635  0.040850  0.520307  0.911449  1.000000 -0.307523
# fg%    -0.046756  0.057384  0.061996 -0.206691  0.095364 -0.307523  1.000000
# 3p     -0.026761  0.085476  0.094277  0.138290  0.158757  0.364707 -0.507593
# 3pa    -0.037895  0.066203  0.074954  0.177166  0.189921  0.424317 -0.571612
# 3p%    -0.001064  0.064992  0.068957  0.084111  0.083407  0.184054 -0.286404
# 2p     -0.233101  0.017495  0.013577  0.340286  0.825295  0.627007  0.376844
# 2pa    -0.222569 -0.005382 -0.012928  0.411353  0.812034  0.727599  0.109678
# 2p%    -0.062145  0.057188  0.066399 -0.187233  0.159801 -0.212816  0.914508
# efg%    0.001459  0.132031  0.143843 -0.215693  0.051761 -0.253425  0.760384
# ft     -0.309109  0.054256  0.055947  0.437306  0.659566  0.650775 -0.045064
# fta    -0.317812  0.044785  0.045233  0.421868  0.628335  0.553848  0.133444
# ft%     0.065084  0.007943  0.011278 -0.015910  0.141877  0.278449 -0.391189
# orb    -0.158757  0.084209  0.085129  0.015935 -0.055949 -0.248727  0.497336
# drb    -0.094762  0.107084  0.109750  0.054602  0.049435 -0.134550  0.440826
# trb    -0.121187  0.104056  0.106279  0.043177  0.015666 -0.181142  0.484010
# ast    -0.032348  0.019539  0.023981  0.202926  0.010852  0.132420 -0.322074
# stl    -0.242685  0.099247  0.096977  0.398754  0.119536  0.239959 -0.324934
# blk    -0.082462  0.025358  0.024269 -0.095689 -0.044975 -0.236866  0.458480
# tov    -0.199429 -0.098736 -0.096117  0.318374  0.348122  0.392739 -0.139131
# pf     -0.243175  0.083663  0.080038  0.074856  0.065947 -0.022151  0.234106
# pts    -0.299108  0.084327  0.087513  0.490606  0.938199  0.918691 -0.057302
# salary  0.434744 -0.148460 -0.135707 -0.188678  0.186812  0.136174  0.105124
#
#               3p       3pa       3p%  ...       orb       drb       trb  \
# age    -0.026761 -0.037895 -0.001064  ... -0.158757 -0.094762 -0.121187
# 2p%    -0.174768 -0.182532  0.319004 -0.027006  0.144160  0.060759  0.209045
# efg%   -0.120277 -0.193920  0.134572 -0.106687  0.040836  0.029557  0.160328
# ft      0.048279  0.187115  0.003643  0.467785  0.170230  0.828892  0.069248
# fta    -0.030056  0.141550  0.185713  0.483205  0.296120  0.747892  0.087285
# ft%     0.195927  0.036529 -0.504271 -0.018310 -0.309979  0.271451  0.004327
# orb    -0.554546 -0.284484  0.683872 -0.211264  0.474154 -0.176216 -0.034803
# drb    -0.491281 -0.203274  0.692357 -0.109382  0.409447 -0.035588  0.124228
# trb    -0.540581 -0.243348  0.728085 -0.149766  0.454630 -0.085709  0.078139
# ast     1.000000  0.540378 -0.516997  0.575311 -0.332601  0.088405 -0.015221
# stl     0.540378  1.000000 -0.260545  0.374066 -0.051550  0.204986 -0.088435
# blk    -0.516997 -0.260545  1.000000 -0.166705  0.380081 -0.135288  0.023983
# tov     0.575311  0.374066 -0.166705  1.000000  0.095822  0.435901  0.084360
# pf     -0.332601 -0.051550  0.380081  0.095822  1.000000  0.050358 -0.072260
# pts     0.088405  0.204986 -0.135288  0.435901  0.050358  1.000000  0.167004
# salary -0.015221 -0.088435  0.023983  0.084360 -0.072260  0.167004  1.000000
#
# [27 rows x 27 columns]

# %%
sns.heatmap(cor_map, cmap='vlag')
plt.show()

# %%
nba_wins = pd.read_csv(r'Team_records.csv')
nba_wins
# Out:
#          season   Lg                 team  wins  loss  win_loss_pctg  finish  \
# 0     2017-2018  NBA       Boston Celtics    29    10          0.744       1
# 1     2016-2017  NBA      Boston Celtics*    53    29          0.646       1
# 2     2015-2016  NBA      Boston Celtics*    48    34          0.585       2
# 3     2014-2015  NBA      Boston Celtics*    40    42          0.488       2
# 4     2013-2014  NBA       Boston Celtics    25    57          0.305       4
# ...         ...  ...                  ...   ...   ...            ...     ...
# 1478  1999-2000  NBA  Vancouver Grizzlies    22    60          0.268       7
# 1479  1998-2099  NBA  Vancouver Grizzlies     8    42          0.160       7
# 1480  1997-2098  NBA  Vancouver Grizzlies    19    63          0.232       6
# 1481  1996-2097  NBA  Vancouver Grizzlies    14    68          0.171       7
# 1482  1995-2096  NBA  Vancouver Grizzlies    15    67          0.183       7
#
#       simple_rating_system  offensive_rating  relative_offensive_rating  \
# 0                     4.38             108.0                        0.2
# 1                     2.25             111.2                        2.4
# 2                     2.84             106.8                        0.4
# 3                    -0.40             104.7                       -0.9
# 4                    -4.97             102.9                       -3.8
# ...                    ...               ...                        ...
# 1478                 -5.10             102.3                       -1.8
# 1479                 -8.94              98.4                       -3.8
# 1480                 -7.47             104.1                       -0.9
# 1481                -10.17             100.3                       -6.4
# 1482                 -9.55              97.6                      -10.0
#
#       deffense_rtg  relative_defensive_rating                Playoffs  \
# 0            102.8                       -5.0                     NaN
# 1            108.4                       -0.4    Lost E. Conf. Finals
# 2            103.6                       -2.8  Lost E. Conf. 1st Rnd.
# 3            104.5                       -1.1  Lost E. Conf. 1st Rnd.
# 4            107.7                        1.0                     NaN
# ...            ...                        ...                     ...
# 1478         108.5                        4.4                     NaN
# 1479         107.9                        5.7                     NaN
# 1480         112.0                        7.0                     NaN
# 1481         111.8                        5.1                     NaN
# 1482         108.5                        0.9                     NaN
#
#         top_ws_player win_shares
# 0           K. Irving        5.7
# 1          I. Thomas        12.5
# 2          I. Thomas         9.7
# 3          T. Zeller         6.5
# 4            B. Bass         5.1
# ...               ...        ...
# 1478  S. Abdur-Rahim         8.8
# 1479  S. Abdur-Rahim         4.6
# 1480  S. Abdur-Rahim         6.9
# 1481      G. Anthony         3.5
# 1482      G. Anthony         4.8
#
# [1483 rows x 15 columns]

# %%
filtered_data = nba_wins[nba_wins['season'] >= '2002-2003']

filtered_data['season'].unique()
# Out:
# array(['2017-2018', '2016-2017', '2015-2016', '2014-2015', '2013-2014',
#        '2012-2013', '2011-2012', '2010-2011', '2009-2010', '2008-2009',
#        '2007-2008', '2006-2007', '2005-2006', '2004-2005', '2003-2004',
#        '2002-2003'], dtype=object)

# %%
filtered_data.groupby('team')['season'].nunique()
# Out:
# team
# Atlanta Hawks           6
# Atlanta Hawks*         10
# Boston Celtics          4
# Boston Celtics*        12
# Brooklyn Nets           3
#                        ..
# Toronto Raptors*        6
# Utah Jazz               9
# Utah Jazz*              7
# Washington Wizards      9
# Washington Wizards*     7
# Name: season, Length: 69, dtype: int64

# %%
filtered_data['team'] = filtered_data['team'].str.replace('*', '', regex=False)
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 478 entries, 0 to 1475
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   season                     478 non-null    object
#  1   Lg                         478 non-null    object
#  2   team                       478 non-null    object
#  3   wins                       478 non-null    int64
#  4   loss                       478 non-null    int64
#  5   win_loss_pctg              478 non-null    float64
#  6   finish                     478 non-null    int64
#  7   simple_rating_system       478 non-null    float64
#  8   offensive_rating           478 non-null    float64
#  9   relative_offensive_rating  478 non-null    float64
#  10  deffense_rtg               478 non-null    float64
#  11  relative_defensive_rating  478 non-null    float64
#  12  Playoffs                   240 non-null    object
#  13  top_ws_player              478 non-null    object
#  14  win_shares                 478 non-null    object
# dtypes: float64(6), int64(3), object(6)
# memory usage: 59.8+ KB
# /var/folders/px/2jjd4x7j5n9gx8819mdg0rgw0000gq/T/ipykernel_58610/1229014954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['team'] = filtered_data['team'].str.replace('*', '', regex=False)

# %%
filtered_data.season.max()
# Out:
# '2017-2018'

# %%
filtered_data.season.min()
# Out:
# '2002-2003'

# %%
matched_wins = matched_players.merge(filtered_data, on=['team','season'], how='left')
matched_wins['win_shares'] = pd.to_numeric(matched_wins['win_shares'], errors='coerce')

# %%
matched_wins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player                     366 non-null    object
#  1   pos                        366 non-null    object
#  2   age                        366 non-null    int64
#  3   tm                         366 non-null    object
#  4   g                          366 non-null    int64
#  5   gs                         366 non-null    int64
#  6   mp                         366 non-null    float64
#  7   fg                         366 non-null    float64
#  8   fga                        366 non-null    float64
#  9   fg%                        366 non-null    float64
#  10  3p                         366 non-null    float64
#  11  3pa                        366 non-null    float64
#  12  3p%                        358 non-null    float64
#  13  2p                         366 non-null    float64
#  14  2pa                        366 non-null    float64
#  15  2p%                        366 non-null    float64
#  16  efg%                       366 non-null    float64
#  17  ft                         366 non-null    float64
#  18  fta                        366 non-null    float64
#  19  ft%                        366 non-null    float64
#  20  orb                        366 non-null    float64
#  21  drb                        366 non-null    float64
#  22  trb                        366 non-null    float64
#  23  ast                        366 non-null    float64
#  24  stl                        366 non-null    float64
#  25  blk                        366 non-null    float64
#  26  tov                        366 non-null    float64
#  27  pf                         366 non-null    float64
#  28  pts                        366 non-null    float64
#  29  season                     366 non-null    object
#  30  team                       366 non-null    object
#  31  salary                     366 non-null    float64
#  32  position                   366 non-null    object
#  33  Lg                         353 non-null    object
#  34  wins                       353 non-null    float64
#  35  loss                       353 non-null    float64
#  36  win_loss_pctg              353 non-null    float64
#  37  finish                     353 non-null    float64
#  38  simple_rating_system       353 non-null    float64
#  39  offensive_rating           353 non-null    float64
#  40  relative_offensive_rating  353 non-null    float64
#  41  deffense_rtg               353 non-null    float64
#  42  relative_defensive_rating  353 non-null    float64
#  43  Playoffs                   263 non-null    object
#  44  top_ws_player              353 non-null    object
#  45  win_shares                 208 non-null    float64
# dtypes: float64(34), int64(3), object(9)
# memory usage: 131.7+ KB

# %%
cor_map_wins = matched_wins.select_dtypes(include='number').corr()
cor_map_wins
# Out:
#                                 age         g        gs        mp        fg  \
# age                        1.000000 -0.111819 -0.124159 -0.353342 -0.272906
# g                         -0.111819  1.000000  0.996497  0.259444  0.069332
# gs                        -0.124159  0.996497  1.000000  0.259037  0.070474
# mp                        -0.353342  0.259444  0.259037  1.000000  0.456276
# fg                        -0.272906  0.069332  0.070474  0.456276  1.000000
# fga                       -0.239322  0.041635  0.040850  0.520307  0.911449
# fg%                       -0.046756  0.057384  0.061996 -0.206691  0.095364
# 3p                        -0.026761  0.085476  0.094277  0.138290  0.158757
# 3pa                       -0.037895  0.066203  0.074954  0.177166  0.189921
# 3p%                       -0.001064  0.064992  0.068957  0.084111  0.083407
# 2p                        -0.233101  0.017495  0.013577  0.340286  0.825295
# 2pa                       -0.222569 -0.005382 -0.012928  0.411353  0.812034
# 2p%                       -0.062145  0.057188  0.066399 -0.187233  0.159801
# efg%                       0.001459  0.132031  0.143843 -0.215693  0.051761
# ft                        -0.309109  0.054256  0.055947  0.437306  0.659566
# fta                       -0.317812  0.044785  0.045233  0.421868  0.628335
# ft%                        0.065084  0.007943  0.011278 -0.015910  0.141877
# orb                       -0.158757  0.084209  0.085129  0.015935 -0.055949
# drb                       -0.094762  0.107084  0.109750  0.054602  0.049435
# trb                       -0.121187  0.104056  0.106279  0.043177  0.015666
# ast                       -0.032348  0.019539  0.023981  0.202926  0.010852
# stl                       -0.242685  0.099247  0.096977  0.398754  0.119536
# blk                       -0.082462  0.025358  0.024269 -0.095689 -0.044975
# tov                       -0.199429 -0.098736 -0.096117  0.318374  0.348122
# pf                        -0.243175  0.083663  0.080038  0.074856  0.065947
# pts                       -0.299108  0.084327  0.087513  0.490606  0.938199
# deffense_rtg               0.227164 -0.015149  0.140452  0.157208  0.116749
# relative_defensive_rating  0.267757 -0.084773  0.097741  0.126772  0.077914
# win_shares                 0.139587  0.181579  0.165192  0.139570  0.075647
#
#                            ...      wins      loss  win_loss_pctg    finish  \
# age                        ...  0.077171 -0.030023       0.064216 -0.089424
# g                          ...  0.338578 -0.217514       0.295758 -0.245268
# gs                         ...  0.339746 -0.226842       0.302486 -0.253516
# mp                         ... -0.079960  0.237789      -0.203484  0.171452
# fg                         ... -0.095337  0.094425      -0.114395  0.095365
# fga                        ... -0.204464  0.208377      -0.240952  0.202909
# fg%                        ...  0.254864 -0.248664       0.283262 -0.248332
# 3p                         ... -0.077890 -0.111330       0.045801 -0.016684
# 3pa                        ... -0.128009 -0.058675      -0.014688  0.023446
# 3p%                        ...  0.014575 -0.068522       0.057291 -0.034588
# 2p                         ... -0.041168  0.150773      -0.130642  0.096134
# 2pa                        ... -0.117941  0.264823      -0.243157  0.197647
# 2p%                        ...  0.223555 -0.336352       0.334448 -0.294854
# efg%                       ...  0.262538 -0.407838       0.401614 -0.334229
# ft                         ... -0.121485  0.160997      -0.172911  0.109284
# fta                        ... -0.102301  0.159374      -0.165637  0.083787
# ft%                        ... -0.029491 -0.011576       0.001435  0.069577
# orb                        ... -0.021074  0.050750      -0.053469  0.039627
# drb                        ... -0.036017 -0.001201      -0.026633  0.016246
# trb                        ... -0.034964  0.016696      -0.038396  0.024613
# ast                        ... -0.032959 -0.011062      -0.006319 -0.016652
# stl                        ... -0.052657  0.034393      -0.051140  0.041590
# blk                        ...  0.067366 -0.068999       0.068854  0.020109
# tov                        ... -0.168579  0.129156      -0.174323  0.087114
# pf                         ... -0.056764  0.135623      -0.125767  0.073268
# pts                        ... -0.123646  0.100491      -0.130999  0.101228
# salary                     ... -0.185362 -0.175799       0.041614 -0.101183
# wins                       ...  1.000000 -0.489587       0.796553 -0.617433
# loss                       ... -0.489587  1.000000      -0.904013  0.728771
# win_loss_pctg              ...  0.796553 -0.904013       1.000000 -0.791365
# finish                     ... -0.617433  0.728771      -0.791365  1.000000
# simple_rating_system       ...  0.757567 -0.865969       0.952047 -0.727405
# offensive_rating           ...  0.446209 -0.578625       0.611483 -0.533639
# relative_offensive_rating  ...  0.521290 -0.612922       0.671599 -0.535658
# deffense_rtg               ... -0.485025  0.475039      -0.552516  0.378235
# relative_defensive_rating  ... -0.538291  0.588272      -0.654580  0.504814
# win_shares                 ...  0.444536 -0.449581       0.453250 -0.194436
#
#                            simple_rating_system  offensive_rating  \
# age                                    0.026088          0.010529
# g                                      0.290431          0.235835
# gs                                     0.297505          0.246677
# mp                                    -0.198167         -0.190721
# fg                                    -0.078344          0.092970
# fga                                   -0.201963         -0.046827
# fg%                                    0.276322          0.313771
# 3p                                     0.079904          0.212625
# 3pa                                    0.020152          0.158350
# 3p%                                    0.055643          0.177244
# 2p                                    -0.116930         -0.034300
# 2pa                                   -0.228379         -0.170659
# 2p%                                    0.343566          0.434986
# blk                                        -0.153332    0.001663
# tov                                         0.123420    0.112697
# pf                                          0.085535   -0.136219
# pts                                         0.254390    0.237379
# salary                                      0.017125    0.024432
# wins                                       -0.538291    0.444536
# loss                                        0.588272   -0.449581
# win_loss_pctg                              -0.654580    0.453250
# finish                                      0.504814   -0.194436
# simple_rating_system                       -0.672169    0.440231
# offensive_rating                            0.044243    0.382321
# relative_offensive_rating                   0.045806    0.430915
# deffense_rtg                                0.902627   -0.078051
# relative_defensive_rating                   1.000000   -0.110211
# win_shares                                 -0.110211    1.000000
#
# [37 rows x 37 columns]

# %%
sns.heatmap(cor_map_wins, cmap='vlag')
plt.show()

# %% [markdown]
# why are all of the data not being brought back in when merging into the two tables

# %%
matched_wins['value_score'] = (
    0.15 * matched_wins['pts'] +
    0.08 * matched_wins['ast'] +
    0.05 * matched_wins['trb'] +
    0.08 * matched_wins['efg%'] +
    0.06 * (matched_wins['stl'] + matched_wins['blk']) -
    0.05 * matched_wins['tov'] +
    0.05 * matched_wins['mp'] +
    0.10 * matched_wins['win_loss_pctg'] 
)
#putting the season in the first column
matched_wins = matched_wins.reindex(
    columns=['season'] + [col for col in matched_wins.columns if col != 'season']
)

#scaling the max out of 10
scaler = MinMaxScaler(feature_range=(0, 10))
matched_wins['value_score_scaled'] = scaler.fit_transform(matched_wins[['value_score']])

# %%
matched_wins.describe()
# Out:
#               age           g          gs          mp          fg         fga  \
# count  366.000000  366.000000  366.000000  366.000000  366.000000  366.000000
# mean    27.480874   71.855191   71.653005   35.715574    7.593169   15.939617
# std      3.698710   11.364126   11.466082    2.987160    1.588894    3.493358
# min     20.000000    5.000000    5.000000   18.200000    2.900000    5.700000
# 25%     25.000000   67.250000   67.000000   34.000000    6.525000   13.600000
# 50%     27.000000   76.000000   75.500000   35.950000    7.700000   16.100000
# 75%     30.000000   80.000000   80.000000   37.700000    8.700000   18.300000
# max     39.000000   82.000000   82.000000   43.100000   12.200000   27.200000
#
#              fg%          3p         3pa         3p%  ...  win_loss_pctg  \
# count  366.00000  366.000000  366.000000  358.000000  ...     353.000000
# mean     0.47947    1.136612    3.115301    0.313198  ...       0.600901
# std      0.04673    0.994904    2.523324    0.128542  ...       0.129149
# min      0.35800    0.000000    0.000000    0.000000  ...       0.183000
# 25%      0.44725    0.100000    0.400000    0.286000  ...       0.514000
# 50%      0.47300    1.100000    3.200000    0.343000  ...       0.610000
# 75%      0.50475    1.800000    4.900000    0.383750  ...       0.695000
# max      0.71400    5.100000   11.200000    1.000000  ...       0.890000
#
#            finish  simple_rating_system  offensive_rating  \
# count  353.000000            353.000000        353.000000
# mean     2.147309              2.761416        108.093484
# std      1.342424              3.817764          3.493230
# min      1.000000             -9.500000         97.000000
# 25%      1.000000              0.020000        105.700000
# 50%      2.000000              3.030000        108.300000
# 75%      3.000000              5.450000        110.900000
# max      7.000000             11.350000        115.600000
#
#        relative_offensive_rating  deffense_rtg  relative_defensive_rating  \
# count                 353.000000    353.000000                 353.000000
# mean                    1.597734    104.979603                  -1.516147
# std                     3.002110      3.417815                   3.067979
# min                    -7.000000     94.100000                  -8.800000
# 25%                    -0.600000    102.800000                  -3.800000
# 50%                     1.600000    104.700000                  -1.400000
# 75%                     3.900000    107.100000                   0.500000
# max                     8.400000    114.400000                   8.200000
#
#        win_shares  value_score  value_score_scaled
# count  208.000000   353.000000          353.000000
# mean    13.007692     5.757893            5.550181
# std      2.484141     0.827622            1.602398
# min     10.000000     2.891280            0.000000
# 25%     10.900000     5.191040            4.452671
# 50%     12.600000     5.757100            5.548646
# 75%     14.500000     6.316100            6.630951
# max     20.300000     8.056180           10.000000
#
# [8 rows x 39 columns]

# %%
matched_wins.sort_values('value_score_scaled', ascending=False).head(50)
# Out:
#         season                 player    pos  age   tm   g  gs    mp    fg  \
# 162  2005-2006            Kobe Bryant     SG   27  LAL  80  80  41.0  12.2
# 277  2005-2006          Allen Iverson     PG   30  PHI  72  72  43.1  11.3
# 57   2005-2006           LeBron James     SF   21  CLE  79  79  42.5  11.1
# 264  2002-2003          Tracy McGrady     SG   23  ORL  75  74  39.4  11.1
# 262  2013-2014           Kevin Durant     SF   25  OKC  81  81  38.5  10.5
# 59   2007-2008           LeBron James     SF   23  CLE  75  74  40.4  10.6
# 69   2009-2010           LeBron James     SF   25  CLE  76  76  39.0  10.1
# 168  2006-2007            Kobe Bryant     SG   28  LAL  77  77  40.8  10.6
# 201  2008-2009            Dwyane Wade     SG   27  MIA  79  79  38.6  10.8
# 125  2017-2018           James Harden     SG   28  HOU  72  72  35.4   9.0
# 61   2008-2009           LeBron James     SF   24  CLE  81  81  37.7   9.7
# 359  2005-2006         Gilbert Arenas     PG   24  WAS  80  80  42.3   9.3
# 251  2009-2010           Kevin Durant     SF   21  OKC  82  82  39.5   9.7
# 130  2015-2016           James Harden     SG   26  HOU  82  82  38.1   8.7
# 114  2015-2016          Stephen Curry     PG   27  GSW  79  79  34.2  10.2
# 58   2006-2007           LeBron James     SF   22  CLE  78  78  40.9   9.9
# 182  2012-2013           LeBron James     PF   28  MIA  76  76  37.9  10.1
# 161  2007-2008            Kobe Bryant     SG   29  LAL  82  82  38.9   9.5
# 357  2006-2007         Gilbert Arenas     PG   25  WAS  74  73  39.8   8.7
# 252  2012-2013           Kevin Durant     SF   24  OKC  81  81  38.5   9.0
# 236  2017-2018          Anthony Davis     PF   24  NOP  75  75  36.4  10.4
# 254  2014-2015      Russell Westbrook     PG   26  OKC  67  67  34.4   9.4
# 63   2016-2017           LeBron James     SF   32  CLE  74  74  37.8   9.9
# 273  2003-2004          Tracy McGrady     SG   24  ORL  67  67  39.9   9.7
# 173  2002-2003       Shaquille O'Neal      C   30  LAL  67  66  37.8  10.4
# 185  2010-2011           LeBron James     SF   26  MIA  79  79  38.8   9.6
# 255  2017-2018      Russell Westbrook     PG   29  OKC  80  80  36.4   9.5
# 196  2011-2012           LeBron James     SF   27  MIA  62  62  37.5  10.0
# 237  2016-2017          Anthony Davis      C   23  NOP  75  75  36.1  10.3
# 210  19.6  ...                  5.86             105.9
# 250  19.7  ...                  6.44             109.8
# 206  18.7  ...                 -0.54             109.4
# 118  18.1  ...                  3.82             107.0
# 82   22.4  ...                  1.69             107.6
# 186  17.6  ...                  4.15             110.9
# 83   19.0  ...                  3.74             110.0
# 171  20.4  ...                  1.48             107.8
# 278  20.2  ...                 -3.26             103.6
# 84   21.8  ...                  4.15             111.8
# 128  21.3  ...                  4.27             106.2
# 211  18.1  ...                  2.46             106.1
# 244  21.3  ...                 -1.40             108.3
# 245  22.2  ...                  3.73             111.1
# 159  23.0  ...                  1.96             106.0
# 213  18.5  ...                  3.10             108.9
# 263  19.7  ...                  3.81             111.2
# 305  19.9  ...                 -3.29             107.3
#
#      relative_offensive_rating  deffense_rtg  relative_defensive_rating  \
# 162                        2.2         105.7                       -0.5
# 277                       -0.2         108.1                        1.9
# 57                         1.6         105.4                       -0.8
# 264                        1.6         105.0                        1.4
# 262                        3.8         103.9                       -2.8
# 59                        -1.5         106.4                       -1.1
# 69                         3.6         104.1                       -3.5
# 168                        2.1         108.6                        2.1
# 201                       -0.5         107.6                       -0.7
# 125                        7.4         106.7                       -1.1
# 61                         4.1         102.4                       -5.9
# 359                        3.1         107.3                        1.1
# 251                        0.7         104.6                       -3.0
# 130                        1.9         108.1                        1.7
# 114                        8.1         103.8                       -2.6
# 58                        -1.0         101.3                       -5.2
# 182                        6.4         103.7                       -2.2
# 161                        5.5         105.5                       -2.0
# 357                        3.6         110.6                        4.1
# 252                        6.5         102.6                       -3.3
# 236                        2.8         110.6                        2.8
# 254                        2.2         105.5                       -0.1
# 63                         4.8         110.3                        1.5
# 273                       -0.2         110.4                        7.5
# 173                        3.6         104.7                        1.1
# 185                        4.4         103.5                       -3.8
# 255                       -0.2         104.3                       -3.5
# 196                        2.0         100.2                       -4.4
# 237                       -3.6         107.4                       -1.4
# 188                       -2.2         105.3                       -1.2
# 204                        2.5         104.5                       -1.7
# 260                        6.7         105.6                       -0.8
# 210                        3.0          99.7                       -3.2
# 250                        5.2         103.2                       -1.4
# 206                        1.6         109.8                        2.0
# 118                        1.4         103.4                       -2.2
# 82                         1.1         105.9                       -0.6
# 186                        4.2         105.8                       -0.9
# 83                         2.5         106.3                       -1.2
# 171                        1.9         106.6                        0.7
# 278                       -2.9         106.9                        0.4
# 84                         4.2         107.5                       -0.1
# 128                        0.1         101.7                       -4.4
# 211                        2.5         103.8                        0.2
# 244                        1.6         109.1                        2.4
# 245                        5.2         106.3                        0.4
# 159                        1.4         104.4                       -0.2
# 213                        2.2         106.2                       -0.5
# 263                        3.9         107.2                       -0.1
# 305                       -1.5         111.3                        2.5
#
#                    Playoffs      top_ws_player  win_shares  value_score  \
# 162  Lost W. Conf. 1st Rnd.         K. Bryant         15.3      8.05618
# 277                     NaN        A. Iverson         10.6      7.89066
# 57      Lost E. Conf. Semis          L. James         16.3      7.79420
# 264  Lost E. Conf. 1st Rnd.        T. McGrady         16.1      7.66160
# 262    Lost W. Conf. Finals         K. Durant         19.2      7.59680
# 59      Lost E. Conf. Semis          L. James         15.2      7.59134
# 69      Lost E. Conf. Semis          L. James         18.5      7.56200
# 168  Lost W. Conf. 1st Rnd.         K. Bryant         13.0      7.53736
# 201  Lost E. Conf. 1st Rnd.           D. Wade         14.7      7.44368
# 125                     NaN         J. Harden          NaN      7.35078
# 61     Lost E. Conf. Finals          L. James         20.3      7.24190
# 359  Lost E. Conf. 1st Rnd.         G. Arenas         13.6      7.21776
# 251  Lost W. Conf. 1st Rnd.         K. Durant         16.1      7.17512
# 130  Lost W. Conf. 1st Rnd.         J. Harden         13.3      7.15896
# 114             Lost Finals          S. Curry         17.9      7.14340
# 58              Lost Finals          L. James         13.7      7.03456
# 182              Won Finals          L. James         19.3      7.03374
# 161             Lost Finals         K. Bryant         13.8      7.02974
# 357  Lost E. Conf. 1st Rnd.         G. Arenas         10.8      7.01472
# 252     Lost W. Conf. Semis         K. Durant         18.9      7.00792
# 236                     NaN          A. Davis          NaN      7.00556
# 254                     NaN      R. Westbrook         10.6      6.99730
# 63              Lost Finals          L. James         12.9      6.98872
# 273                     NaN        T. McGrady          NaN      6.98344
# 173     Lost W. Conf. Semis         K. Bryant         14.9      6.95992
# 185             Lost Finals          L. James         15.6      6.94598
# 255                     NaN          S. Adams          NaN      6.93876
# 196              Won Finals          L. James         14.5      6.93702
# 237                     NaN          A. Davis         11.0      6.93594
# 188  Lost E. Conf. 1st Rnd.           D. Wade          NaN      6.92186
# 204              Won Finals           D. Wade         14.4      6.91632
# 260    Lost W. Conf. Finals         K. Durant         14.5      6.89994
# 210    Lost W. Conf. Finals        K. Garnett         18.3      6.89786
# 250             Lost Finals         K. Durant         12.2      6.88496
# 206                     NaN  G. Antetokounmpo          NaN      6.87750
# 118    Lost W. Conf. Finals         J. Harden         16.4      6.86018
# 82   Lost W. Conf. 1st Rnd.          M. Camby          NaN      6.85902
# 186             Lost Finals          L. James         15.9      6.85270
# 83   Lost W. Conf. 1st Rnd.        A. Iverson         11.6      6.84404
# 171  Lost W. Conf. 1st Rnd.         K. Bryant         10.9      6.79722
# 278                     NaN       A. Iguodala          NaN      6.79698
# 84   Lost W. Conf. 1st Rnd.        N. Hilario         10.8      6.78084
# 128  Lost W. Conf. 1st Rnd.        T. McGrady         12.0      6.77504
# 211  Lost W. Conf. 1st Rnd.        K. Garnett         15.6      6.76784
# 244                     NaN        C. Anthony         10.7      6.76734
# 245     Lost E. Conf. Semis        C. Anthony          NaN      6.76206
# 159     Lost W. Conf. Semis          P. Gasol          NaN      6.76206
# 213                     NaN           K. Love         14.3      6.75072
# 263    Lost W. Conf. Finals         K. Durant         12.0      6.74982
# 305                     NaN        D. Cousins          NaN      6.73384
#
#      value_score_scaled
# 162           10.000000
# 277            9.679529
# 57             9.492768
# 264            9.236036
# 262            9.110573
# 59             9.100002
# 69             9.043195
# 168            8.995489
# 201            8.814111
# 125            8.634243
# 61             8.423435
# 359            8.376697
# 251            8.294139
# 130            8.262851
# 114            8.232725
# 58             8.021995
# 182            8.020407
# 161            8.012662
# 357            7.983581
# 252            7.970416
# 236            7.965846
# 254            7.949854
# 63             7.933242
# 273            7.923019
# 173            7.877481
# 185            7.850491
# 255            7.836512
# 196            7.833143
# 237            7.831052
# 188            7.803791
# 204            7.793065
# 260            7.761351
# 210            7.757323
# 250            7.732347
# 206            7.717904
# 118            7.684369
# 82             7.682124
# 186            7.669887
# 83             7.653120
# 171            7.562470
# 278            7.562005
# 84             7.530756
# 128            7.519526
# 211            7.505586
# 244            7.504618
# 245            7.494395
# 159            7.494395
# 213            7.472439
# 263            7.470696
# 305            7.439757
#
# [50 rows x 48 columns]

# %%
matched_wins.sort_values('value_score_scaled', ascending=False).to_csv('sorted_matched_wins.csv', index=False)

# %%
test_data = matched_wins.dropna()

# %%
import pandas as pd

# Load your CSV
df = test_data

# Check the necessary columns
if 'team' in df.columns and 'win_loss_pctg' in df.columns:
    # Group by team and compute average win percentage
    team_ratings = df.groupby('team')['win_loss_pctg'].mean().sort_values(ascending=False)
    
    # Convert to DataFrame for display
    team_ratings = team_ratings.reset_index().rename(columns={'win_loss_pctg': 'Team_rating'})
    print(team_ratings)
else:
    print("Missing 'TEAM_ABBREVIATION' or 'win_loss_pctg' in dataset.")
# Out:
#                       team  Team_rating
# 0    Golden State Warriors     0.795000
# 1        San Antonio Spurs     0.720462
# 2         Sacramento Kings     0.720000
# 3          Detroit Pistons     0.707273
# 4           Boston Celtics     0.702692
# 5         Dallas Mavericks     0.695300
# 6    Oklahoma City Thunder     0.690200
# 7               Miami Heat     0.676765
# 8             Phoenix Suns     0.670000
# 9       Los Angeles Lakers     0.667100
# 10           Orlando Magic     0.665714
# 11     Cleveland Cavaliers     0.664667
# 12  Minnesota Timberwolves     0.664500
# 13               Utah Jazz     0.642333
# 14  Portland Trail Blazers     0.634333
# 15          Indiana Pacers     0.634000
# 16     Seattle SuperSonics     0.634000
# 17          Denver Nuggets     0.628000
# 18       Memphis Grizzlies     0.619000
# 19     New Orleans Hornets     0.616000
# 20         Toronto Raptors     0.612750
# 21           Chicago Bulls     0.612200
# 22         Houston Rockets     0.608375
# 23           Brooklyn Nets     0.598000
# 24           Atlanta Hawks     0.589333
# 25         New Jersey Nets     0.557000
# 26    New Orleans Pelicans     0.549000
# 27       Charlotte Bobcats     0.537000
# 28         Milwaukee Bucks     0.512000
# 29      Washington Wizards     0.504000

# %%
team_ratings = df

# %%
# Min-max scale the Team_rating column to a 1–10 range
#min_val = team_ratings['Team_rating'].min()
#max_val = team_ratings['Team_rating'].max()

team_ratings['Scaled_Team_Rating'] = 1 + 9 * (team_ratings['Team_rating'] - min_val) / (max_val - min_val)

team_ratings['Scaled_Team_Rating'] = team_ratings['Scaled_Team_Rating'].round(2)


print(team_ratings)
# Out:
#                       team  Team_rating  Scaled_Team_Rating
# 0    Golden State Warriors     0.795000               10.00
# 1        San Antonio Spurs     0.720462                7.69
# 2         Sacramento Kings     0.720000                7.68
# 3          Detroit Pistons     0.707273                7.29
# 4           Boston Celtics     0.702692                7.15
# 5         Dallas Mavericks     0.695300                6.92
# 6    Oklahoma City Thunder     0.690200                6.76
# 7               Miami Heat     0.676765                6.34
# 8             Phoenix Suns     0.670000                6.13
# 9       Los Angeles Lakers     0.667100                6.04
# 10           Orlando Magic     0.665714                6.00
# 11     Cleveland Cavaliers     0.664667                5.97
# 12  Minnesota Timberwolves     0.664500                5.96
# 13               Utah Jazz     0.642333                5.28
# 14  Portland Trail Blazers     0.634333                5.03
# 15          Indiana Pacers     0.634000                5.02
# 16     Seattle SuperSonics     0.634000                5.02
# 17          Denver Nuggets     0.628000                4.84
# 18       Memphis Grizzlies     0.619000                4.56
# 19     New Orleans Hornets     0.616000                4.46
# 20         Toronto Raptors     0.612750                4.36
# 21           Chicago Bulls     0.612200                4.35
# 22         Houston Rockets     0.608375                4.23
# 23           Brooklyn Nets     0.598000                3.91
# 24           Atlanta Hawks     0.589333                3.64
# 25         New Jersey Nets     0.557000                2.64
# 26    New Orleans Pelicans     0.549000                2.39
# 27       Charlotte Bobcats     0.537000                2.02
# 28         Milwaukee Bucks     0.512000                1.25
# 29      Washington Wizards     0.504000                1.00

# %%
team_ratings
# Out:
#                       team  Team_rating  Scaled_Team_Rating
# 0    Golden State Warriors     0.795000               10.00
# 1        San Antonio Spurs     0.720462                7.69
# 2         Sacramento Kings     0.720000                7.68
# 3          Detroit Pistons     0.707273                7.29
# 4           Boston Celtics     0.702692                7.15
# 5         Dallas Mavericks     0.695300                6.92
# 6    Oklahoma City Thunder     0.690200                6.76
# 7               Miami Heat     0.676765                6.34
# 8             Phoenix Suns     0.670000                6.13
# 9       Los Angeles Lakers     0.667100                6.04
# 10           Orlando Magic     0.665714                6.00
# 11     Cleveland Cavaliers     0.664667                5.97
# 12  Minnesota Timberwolves     0.664500                5.96
# 13               Utah Jazz     0.642333                5.28
# 14  Portland Trail Blazers     0.634333                5.03
# 15          Indiana Pacers     0.634000                5.02
# 16     Seattle SuperSonics     0.634000                5.02
# 17          Denver Nuggets     0.628000                4.84
# 18       Memphis Grizzlies     0.619000                4.56
# 19     New Orleans Hornets     0.616000                4.46
# 20         Toronto Raptors     0.612750                4.36
# 21           Chicago Bulls     0.612200                4.35
# 22         Houston Rockets     0.608375                4.23
# 23           Brooklyn Nets     0.598000                3.91
# 24           Atlanta Hawks     0.589333                3.64
# 25         New Jersey Nets     0.557000                2.64
# 26    New Orleans Pelicans     0.549000                2.39
# 27       Charlotte Bobcats     0.537000                2.02
# 28         Milwaukee Bucks     0.512000                1.25
# 29      Washington Wizards     0.504000                1.00

# %%
team_ratings.to_csv("team_ratings.csv", index=False)

# %%
test_data['pts']
# Out:
# 0      17.1
# 3      18.2
# 4      15.2
# 6      15.3
# 8      14.2
#        ...
# 349    21.1
# 352    21.9
# 357    28.4
# 359    29.3
# 364    19.1
# Name: pts, Length: 189, dtype: float64

# %%
PTS_4Q_est = test_data['pts'] * 0.28  # You can adjust the 0.28 based on desired bias

# %%
clutchness_score = PTS_4Q_est * test_data['win_loss_pctg']

# %%
test_data.columns
# Out:
# Index(['season', 'player', 'pos', 'age', 'tm', 'g', 'gs', 'mp', 'fg', 'fga',
#        'fg%', '3p', '3pa', '3p%', '2p', '2pa', '2p%', 'efg%', 'ft', 'fta',
#        'ft%', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts',
#        'team', 'salary', 'position', 'Lg', 'wins', 'loss', 'win_loss_pctg',
#        'finish', 'simple_rating_system', 'offensive_rating',
#        'relative_offensive_rating', 'deffense_rtg',
#        'relative_defensive_rating', 'Playoffs', 'top_ws_player', 'win_shares',
#        'value_score', 'value_score_scaled'],
#       dtype='object')

# %%
estimated_4Q_pts = test_data['pts'] * 0.28
adjusted_4Q_pts = estimated_4Q_pts * (test_data['offensive_rating'] / 100)
clutchness_score1 = adjusted_4Q_pts * test_data['win_loss_pctg']

# %%
clutchness_score1
# Out:
# 0      2.943830
# 3      2.903482
# 4      2.616738
# 6      2.440839
# 8      2.874147
#          ...
# 349    4.430657
# 352    4.180258
# 357    4.377576
# 359    4.591090
# 364    2.944074
# Length: 189, dtype: float64

# %%
clutchness_score = (0.6 * adjusted_4Q_pts) + (0.4 * (test_data['win_loss_pctg'] * 10))

# %%
clutchness_score
# Out:
# 0      5.359313
# 3      5.392114
# 4      5.023834
# 6      4.875194
# 8      5.253486
#          ...
# 349    6.669982
# 352    6.520403
# 357    7.253091
# 359    7.428183
# 364    5.532889
# Length: 189, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# Step 1: Estimate 4th quarter points (assume 28% of total PTS)
test_data['PTS_4Q_est'] = test_data['pts'] * 0.28

# Step 2: Adjust for offensive rating
test_data['PTS_4Q_adj'] = test_data['PTS_4Q_est'] * (test_data['offensive_rating'] / 100)

# Step 3: Compute raw clutchness score using team win % as multiplier
test_data['clutch_rating'] = test_data['PTS_4Q_adj'] * test_data['win_loss_pctg']

# Step 4 (Optional): Normalize clutch rating to 1–10 scale
scaler = MinMaxScaler(feature_range=(1, 10))
test_data['clutch_rating_scaled'] = scaler.fit_transform(test_data[['clutch_rating']])
# Out:
# /var/folders/px/2jjd4x7j5n9gx8819mdg0rgw0000gq/T/ipykernel_58610/3115167853.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['PTS_4Q_est'] = test_data['pts'] * 0.28
# /var/folders/px/2jjd4x7j5n9gx8819mdg0rgw0000gq/T/ipykernel_58610/3115167853.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['PTS_4Q_adj'] = test_data['PTS_4Q_est'] * (test_data['offensive_rating'] / 100)
# /var/folders/px/2jjd4x7j5n9gx8819mdg0rgw0000gq/T/ipykernel_58610/3115167853.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['clutch_rating'] = test_data['PTS_4Q_adj'] * test_data['win_loss_pctg']
# /var/folders/px/2jjd4x7j5n9gx8819mdg0rgw0000gq/T/ipykernel_58610/3115167853.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['clutch_rating_scaled'] = scaler.fit_transform(test_data[['clutch_rating']])

# %%
test_data
# Out:
#         season          player pos  age   tm   g  gs    mp   fg   fga  ...  \
# 0    2015-2016    Paul Millsap  PF   30  ATL  81  81  32.7  6.2  13.2  ...
# 3    2010-2011     Joe Johnson  SG   29  ATL  72  72  35.5  7.1  16.1  ...
# 4    2015-2016      Al Horford   C   29  ATL  82  82  32.1  6.5  12.8  ...
# 6    2010-2011      Al Horford   C   24  ATL  77  77  35.1  6.7  12.0  ...
# 8    2009-2010      Al Horford   C   23  ATL  81  81  35.1  5.8  10.5  ...
# ..         ...             ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 349  2007-2008   Carlos Boozer  PF   26  UTA  81  81  34.9  8.8  16.0  ...
# 352  2016-2017  Gordon Hayward  SF   26  UTA  73  73  34.5  7.5  15.8  ...
# 357  2006-2007  Gilbert Arenas  PG   25  WAS  74  73  39.8  8.7  20.9  ...
# 359  2005-2006  Gilbert Arenas  PG   24  WAS  80  80  42.3  9.3  20.9  ...
# 364  2006-2007    Caron Butler  SF   26  WAS  63  63  39.3  7.2  15.5  ...
#
#      relative_defensive_rating                Playoffs  top_ws_player  \
# 0                         -5.0     Lost E. Conf. Semis    P. Millsap
# 3                         -0.3     Lost E. Conf. Semis    A. Horford
# 4                         -5.0     Lost E. Conf. Semis    P. Millsap
# 6                         -0.3     Lost E. Conf. Semis    A. Horford
# 8                         -0.9     Lost E. Conf. Semis    A. Horford
# ..                         ...                     ...            ...
# 349                       -1.0     Lost W. Conf. Semis   D. Williams
# 352                       -3.5     Lost W. Conf. Semis     R. Gobert
# 357                        4.1  Lost E. Conf. 1st Rnd.     G. Arenas
# 359                        1.1  Lost E. Conf. 1st Rnd.     G. Arenas
# 364                        4.1  Lost E. Conf. 1st Rnd.     G. Arenas
#
#      win_shares  value_score  value_score_scaled  PTS_4Q_est  PTS_4Q_adj  \
# 0          10.1      5.10290            4.282019       4.788    5.032188
# 3          10.1      5.12118            4.317412       5.096    5.406856
# 4          10.1      4.68126            3.465662       4.256    4.473056
# 6          10.1      4.92634            3.940173       4.284    4.545324
# 8          10.9      4.70576            3.513098       3.976    4.449144
# ..          ...          ...                 ...         ...         ...
# 349        11.3      5.74366            5.522624       5.908    6.723304
# 352        14.3      5.64808            5.337567       6.132    6.720672
# 357        10.8      7.01472            7.983581       7.952    8.755152
# 359        13.6      7.21776            8.376697       8.204    8.966972
# 364        10.8      5.58276            5.211098       5.348    5.888148
#
#      clutch_rating  clutch_rating_scaled
# 0         2.943830              3.099092
# 3         2.903482              3.049765
# 4         2.616738              2.699208
# 6         2.440839              2.484165
# 8         2.874147              3.013902
# ..             ...                   ...
# 349       4.430657              4.916800
# 352       4.180258              4.610676
# 357       4.377576              4.851906
# 359       4.591090              5.112935
# 364       2.944074              3.099390
#
# [189 rows x 52 columns]

# %%
top_clutch_players = test_data[test_data['value_score_scaled'] == 10]
top_clutch_players
# Out:
#         season       player pos  age   tm   g  gs    mp    fg   fga  ...  \
# 162  2005-2006  Kobe Bryant  SG   27  LAL  80  80  41.0  12.2  27.2  ...
#
#      relative_defensive_rating                Playoffs  top_ws_player  \
# 162                       -0.5  Lost W. Conf. 1st Rnd.     K. Bryant
#
#      win_shares  value_score  value_score_scaled  PTS_4Q_est  PTS_4Q_adj  \
# 162        15.3      8.05618                10.0       9.912   10.744608
#
#      clutch_rating  clutch_rating_scaled
# 162        5.89879              6.711653
#
# [1 rows x 52 columns]

# %%
test_data.to_csv("team_ratings_clutch_rating.csv", index=False)
